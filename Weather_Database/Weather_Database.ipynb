# %%
# Import the dependencies.
import pandas as pd
import gmaps
import gmaps.datasets
import numpy as np
import matplotlib.pyplot as plt

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Import the requests library.
import requests

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the Google API key.
from config import g_key

# Import the API key.
from config import weather_api_key


#Set Weather URL amd API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 23.7162, 'lat': 37.9795},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 51.3,
#   'feels_like': 49.93,
#   'temp_min': 44.98,
#   'temp_max': 56.16,
#   'pressure': 1015,
#   'humidity': 81},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 68, 'gust': 4},
#  'clouds': {'all': 0},
#  'dt': 1641265578,
#  'sys': {'type': 2,
#   'id': 2018805,
#   'country': 'GR',
#   'sunrise': 1641274881,
#   'sunset': 1641309495},
#  'timezone': 7200,
#  'id': 264371,
#  'name': 'Athens',
#  'cod': 200}

# %%
#Extracting the Item 'weather' a dictionary from the jspon array
weather_dict = city_weather['weather']
weather_dict
# Out:
# [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]

# %%
# Getting the dictionay from list item 0

current_cond_dict = weather_dict[0]
current_cond_dict

#getting the currnet condition from the 'description' key
current_cond = current_cond_dict['description']
current_cond
# Out:
# 'clear sky'

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        weather_dict = city_weather['weather']
        current_cond_dict = weather_dict[0]
        city_current = current_cond_dict['description']
        #city_current = city_weather["main"]["description"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | sao filipe
# Processing Record 3 of Set 1 | santa fe
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | laguna
# Processing Record 8 of Set 1 | ilulissat
# Processing Record 9 of Set 1 | amberley
# Processing Record 10 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 1 | koulikoro
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | nha trang
# Processing Record 15 of Set 1 | ancud
# Processing Record 16 of Set 1 | mayumba
# Processing Record 17 of Set 1 | el vigia
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | gioia tauro
# ...

# %%
# Convert the array of dictionaries into a DataFrame for Pandas.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town -33.9258   18.4232     62.28        82           0
# 1      Sao Filipe  14.8961  -24.4956     73.04        63          51
# 2        Santa Fe -31.6333  -60.7000     82.02        64           7
# 3  Port Elizabeth -33.9180   25.5701     69.10        94          40
# 4         Rikitea -23.1203 -134.9692     78.08        67         100
# 5    Puerto Ayora  -0.7393  -90.3518     71.24        88          93
# 6          Laguna  38.4210 -121.4238     55.60        74          90
# 7       Ilulissat  69.2167  -51.1000     30.22        47         100
# 8        Amberley  39.2048  -84.4280     26.40        82           1
# 9       Koulikoro  14.0000   -7.7500     62.65        26          14
#
#    Wind Speed Country                 Date Current Description
# 0        3.00      ZA  2022-01-04 03:22:34           clear sky
# 1        7.14      CV  2022-01-04 03:23:39       broken clouds
# ...

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0       Cape Town      ZA  2022-01-04 03:22:34 -33.9258   18.4232     62.28
# 1      Sao Filipe      CV  2022-01-04 03:23:39  14.8961  -24.4956     73.04
# 2        Santa Fe      AR  2022-01-04 03:23:39 -31.6333  -60.7000     82.02
# 3  Port Elizabeth      ZA  2022-01-04 03:23:39 -33.9180   25.5701     69.10
# 4         Rikitea      PF  2022-01-04 03:23:40 -23.1203 -134.9692     78.08
# 5    Puerto Ayora      EC  2022-01-04 03:23:40  -0.7393  -90.3518     71.24
# 6          Laguna      US  2022-01-04 03:23:40  38.4210 -121.4238     55.60
# 7       Ilulissat      GL  2022-01-04 03:23:40  69.2167  -51.1000     30.22
# 8        Amberley      US  2022-01-04 03:23:41  39.2048  -84.4280     26.40
# 9       Koulikoro      ML  2022-01-04 03:23:41  14.0000   -7.7500     62.65
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        82           0        3.00           clear sky
# ...

# %%
# Create the output file (CSV).
output_data_file = "/Users/Tim/Documents/OSU_Bootcamp/Challenge_6/Weather_Database/weatherPy_database.csv"
# CSV Path /Users/Tim/Documents/OSU_Bootcamp/Challenge_6/Weather_Database/

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
